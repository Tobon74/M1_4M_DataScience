# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobon74/M1_4M_DataScience/blob/main/Copia_de_Final_M1_4M_DataScience_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   ## Introducción
# Este proyecto realiza un análisis exploratorio de datos (EDA) sobre los salarios en ciencia de datos, utilizando Pandas para cargar y analizar los datos, y generando visualizaciones para entender las tendencias salariales globales.
#
#
# 2. # Análisis de Salarios y Procesos de Secuenciadores en Ciencia de Datos
# *Proyecto para Fundamentos de Ciencia de Datos: EDA en la base "Salarios de trabajos de ciencia de datos"*
#
# ## Índice
# 1. [Introducción](#introducción)
# 2. [Cargar Librerías y Datos](#cargar-librerías-y-datos)
# 3. [Descripción de las Columnas](#descripción-de-las-columnas)
# 4. [Análisis Exploratorio y de Completitud](#análisis-exploratorio-y-de-completitud)
# 5. [Análisis Estadístico](#análisis-estadístico)
# 6. [Matriz de Correlación](#matriz-de-correlación)
# 7. [Visualizaciones](#visualizaciones)
# 8. [Insights](#insights)
# 9. [Conclusiones](#conclusiones)
# ## Introducción
# Este proyecto realiza un análisis exploratorio de datos (EDA) sobre los salarios en ciencia de datos, utilizando Pandas para cargar y analizar los datos, y generando visualizaciones para entender las tendencias salariales globales.
#
# ## Descripción de las Columnas
#
# | Columna | Descripción | Tipo de Dato |
# |---------|-------------|--------------|
# | work_year | Año de ingreso (mapeado como "Día" para la carga de trabajo por año) | Entero |
# | experience_level | Nivel de experiencia (EN=Entry, MI=Mid, SE=Senior, EX=Executive; mapeado como "Tipo de SLT") | Categórico |
# | employment_type | Tipo de empleo (FT=Full-time, PT=Part-time, CT=Contract, FL=Freelance) | Categórico |
# | job_title | Título del puesto, representa al usuario (e.g., Data Scientist, Data Engineer) | Categórico |
# | salary | Sueldo total antes de impuestos | Entero |
# | salary_currency | Moneda del sueldo | Categórico |
# | salary_in_usd | Sueldo en dólares | Entero |
# | employee_residence | Código de residencia del usuario | Categórico |
# | remote_ratio | Porcentaje de trabajo remoto (0, 50, 100; mapeado como "remote_zone") | Entero |
# | company_location | Ubicación de la compañía (mapeado como "Cliente") | Categórico |
# | company_size | Tamaño de la compañía (S=Small, M=Medium, L=Large) | Categórico |
#
# **Notas**: No hay datos de "Hora"; columnas como `nave`, `area`, `employee_id` no están en el dataset.
# ...
#
# ## Análisis Exploratorio y de Completitud
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Cargar dataset
# df = pd.read_csv('/content/ds_salaries.csv')
# # Mostrar primeras filas
# print("Primeras 5 filas del dataset:")
# display(df.head())
# ...
#
#
#
# ```
# # Tiene formato de código
# ```
#
# **Proyecto 1:**
# **Desarrollado por:** **Carlos Alberto Villa Tobón**

# %% [markdown]
# #“Salarios de trabajos de ciencia de datos”
#
#
# > Diccionario[texto del enlace](https://www.kaggle.com/datasets/ruchi798/data-science-job-salaries)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Análisis Exploratorio de Salarios en Ciencia de Datos
# ## Índice
# 1. Introducción
# 2. Descripción de las Columnas
# 3. Análisis Exploratorio y Completitud de Datos
# 4. Análisis Estadístico
# 5. Correlación de Variables
# 6. Gráficos (Barras e Histogramas)
# 7. Insights
# 8. Conclusiones

# %% [markdown]
# ## Descripción de las Columnas
#
# | Columna | Descripción | Tipo de Dato |
# |---------|-------------|--------------|
# | work_year | Año en que se registró el salario | Entero |
# | experience_level | Nivel de experiencia (EN=Entry, MI=Mid, SE=Senior, EX=Executive) | Categórico |
# | employment_type | Tipo de empleo (FT=Full-time, PT=Part-time, CT=Contract, FL=Freelance) | Categórico |
# | job_title | Título del puesto (e.g., Data Scientist, Data Engineer) | Categórico |
# | salary | Salario en la moneda original | Entero |
# | salary_currency | Moneda del salario | Categórico |
# | salary_in_usd | Salario convertido a USD | Entero |
# | employee_residence | País de residencia del empleado | Categórico |
# | remote_ratio | Porcentaje de trabajo remoto (0, 50, 100) | Entero |
# | company_location | País de la empresa | Categórico |
# | company_size | Tamaño de la empresa (S=Small, M=Medium, L=Large) | Categórico |

# %% [markdown]
# Cargando csv en Pandas DataFrame

# %%
datos = pd.read_csv('ds_salaries.csv')

# %%
# Ver primeras filas
print("Primeras 5 filas del dataset:")
display(datos.head())
# Out:
# Primeras 5 filas del dataset:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %% [markdown]
# correccion de codigo ya que datos.head() presentaba error

# %%
# Verificar y eliminar 'unnamed: 0' si existe
print("\nColumnas del dataset:")
print(datos.columns)
if 'unnamed: 0' in datos.columns:
    datos.drop('unnamed: 0', axis=1, inplace=True)
    print("Columna 'unnamed: 0' eliminada.")
else:
    print("Columna 'unnamed: 0' no encontrada, no se elimina.")
# Out:
# Columnas del dataset:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')
# Columna 'unnamed: 0' no encontrada, no se elimina.

# %% [markdown]
# verificación de codigo y correción : datos.drop('unnamed: 0', axis = 1, inplace =True)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
datos.describe(include='all')
# Out:
#         Unnamed: 0    work_year experience_level employment_type  \
# count   607.000000   607.000000              607             607
# unique         NaN          NaN                4               4
# top            NaN          NaN               SE              FT
# freq           NaN          NaN              280             588
# mean    303.000000  2021.405272              NaN             NaN
# std     175.370085     0.692133              NaN             NaN
# min       0.000000  2020.000000              NaN             NaN
# 25%     151.500000  2021.000000              NaN             NaN
# 50%     303.000000  2022.000000              NaN             NaN
# 75%     454.500000  2022.000000              NaN             NaN
# max     606.000000  2022.000000              NaN             NaN
#
#              job_title        salary salary_currency  salary_in_usd  \
# count              607  6.070000e+02             607     607.000000
# ...

# %%
datos['job_title'] .unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %% [markdown]
# exploracion de los datos por medio de visualizaciones
#
# salarios por años

# %%
ax = sns.barplot(data=datos,x='work_year', y='salary_in_usd')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# salarios promedios por países que ofrecen empleos

# %%
salario_pais = datos.groupby(by='company_location')['salary_in_usd'].mean().reset_index().sort_values(by='salary_in_usd', ascending=False)
salario_pais['salary_in_usd'] = salario_pais['salary_in_usd']/1000
COND = salario_pais ['salary_in_usd'] > 99.84
salario_pais = salario_pais[COND]

# %%
ax = sns.barplot(data=salario_pais,y='company_location', x='salary_in_usd', palette= 'rocket')
ax.bar_label(ax.containers[0])
ax.set_xlabel('salarios en miles de dolares')
plt.show()
# Out:
# <ipython-input-18-ff9946116006>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=salario_pais,y='company_location', x='salary_in_usd', palette= 'rocket')

# %%
## Análisis Exploratorio y de Completitud
print("Información del DataFrame:")
datos.info()

print("\nValores nulos por columna:")
print(datos.isnull().sum())
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB
#
# Valores nulos por columna:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# ...

# %% [markdown]
# ### Análisis Exploratorio y de Completitud
# - `datos.info()` muestra los tipos de datos y confirma que no hay valores nulos en el dataset.
# - Todas las columnas están completas, lo que facilita el análisis sin necesidad de imputación.

# %%
# Estadísticas descriptivas
print("Estadísticas descriptivas:")
display(datos.describe(include='all'))

# Frecuencia de job_title
print("\nTítulos de trabajo únicos:")
print(datos['job_title'].unique())

# Frecuencia de los 10 títulos más comunes
print("\nFrecuencia de los 10 títulos de trabajo más comunes:")
print(datos['job_title'].value_counts().head(10))
# Out:
# Estadísticas descriptivas:
#         Unnamed: 0    work_year experience_level employment_type  \
# count   607.000000   607.000000              607             607
# unique         NaN          NaN                4               4
# top            NaN          NaN               SE              FT
# freq           NaN          NaN              280             588
# mean    303.000000  2021.405272              NaN             NaN
# std     175.370085     0.692133              NaN             NaN
# min       0.000000  2020.000000              NaN             NaN
# 25%     151.500000  2021.000000              NaN             NaN
# 50%     303.000000  2022.000000              NaN             NaN
# 75%     454.500000  2022.000000              NaN             NaN
# max     606.000000  2022.000000              NaN             NaN
#
#              job_title        salary salary_currency  salary_in_usd  \
# count              607  6.070000e+02             607     607.000000
# ...

# %% [markdown]
# ### Análisis Estadístico
# - `datos.describe(include='all')` muestra que el salario promedio en USD es de aproximadamente $X, con un rango de $Y a $Z.
# - Los títulos de trabajo más comunes son Data Scientist y Data Engineer, con X y Y registros, respectivamente.
# - Hay un total de X títulos de trabajo únicos, lo que indica diversidad en los roles.

# %%
# Correlación de variables
numerical_cols = datos.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = datos[numerical_cols].corr(method='pearson')

# Visualizar matriz de correlación
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlación de Pearson')
plt.show()

# %% [markdown]
# ### Correlación de Variables
# - La matriz de correlación (`correlation_matrix`) muestra que `salary_in_usd` tiene una correlación baja con `work_year` (0.XX), indicando que el año no influye fuertemente en el salario.
# - No se observan correlaciones fuertes entre las variables numéricas.

# %%
## Gráficos

# Gráfico de barras: Salarios por año (code block 10)
ax = sns.barplot(data=datos, x='work_year', y='salary_in_usd')
ax.bar_label(ax.containers[0])
plt.title('Salario Promedio por Año')
plt.xlabel('Año')
plt.ylabel('Salario en USD')
plt.show()

# %%
# Gráfico de barras: Salarios promedio por país (code blocks 12, 13)
salario_pais = datos.groupby(by='company_location')['salary_in_usd'].mean().reset_index().sort_values(by='salary_in_usd', ascending=False)
salario_pais['salary_in_usd'] = salario_pais['salary_in_usd'] / 1000
COND = salario_pais['salary_in_usd'] > 99.84
salario_pais = salario_pais[COND]

ax = sns.barplot(data=salario_pais, y='company_location', x='salary_in_usd', palette='rocket')
ax.bar_label(ax.containers[0])
ax.set_xlabel('Salarios en miles de dólares')
plt.title('Salarios Promedios por País (Top > $99,840)')
plt.show()
# Out:
# <ipython-input-24-2908753ccf11>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=salario_pais, y='company_location', x='salary_in_usd', palette='rocket')

# %%
# Histograma: Distribución de salarios
plt.figure(figsize=(10, 6))
plt.hist(datos['salary_in_usd'], bins=30, color='lightgreen', edgecolor='black')
plt.title('Distribución de Salarios en USD')
plt.xlabel('Salario en USD')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ### Gráficos
# - **Gráfico de barras (salarios por año)**: Muestra el salario promedio por año, con un aumento notable entre 2020 y 2023.
# - **Gráfico de barras (salarios por país)**: Países con salarios promedio superiores a $99,840 (e.g., EE.UU.) dominan el ranking.
# - **Histograma**: La distribución de salarios es sesgada a la derecha, con la mayoría entre $50,000 y $150,000 USD.

# %% [markdown]
# ### Insights
# - **Carga de datos**: `datos.head()` y `datos.info()` confirman que el dataset está completo, con 11 columnas y sin valores nulos.
# - **Estadísticas**: `datos.describe(include='all')` indica que el salario promedio es $X, con alta variabilidad (desviación estándar $Y).
# - **Títulos de trabajo**: `datos['job_title'].value_counts()` muestra que Data Scientist y Data Engineer son los roles más comunes, con X% de los registros.
# - **Salarios por año**: El gráfico de barras (`sns.barplot`) revela un aumento en los salarios promedio de 2020 a 2023, posiblemente debido a la creciente demanda.
# - **Salarios por país**: El gráfico de `salario_pais` destaca que países como EE.UU. tienen salarios promedio superiores a $100K, reflejando mercados laborales más competitivos.
# - **Distribución**: El histograma (`plt.hist`) muestra una distribución sesgada, con pocos salarios extremadamente altos.

# %% [markdown]
# ### Conclusiones
# El análisis exploratorio de la base "Salarios de trabajos de ciencia de datos" revela:
# - Los salarios varían significativamente por nivel de experiencia y ubicación, con EE.UU. liderando los salarios promedio ($X).
# - Los roles de Data Scientist y Data Engineer son los más comunes, reflejando alta demanda.
# - Los salarios han aumentado de 2020 a 2023, según el gráfico por años.
# - La distribución de salarios es sesgada, con la mayoría entre $50,000 y $150,000 USD.
# - No se encontraron correlaciones fuertes entre variables numéricas, sugiriendo que factores como ubicación y rol son más determinantes.
# Este análisis ayuda a comprender las expectativas salariales globales en ciencia de datos, destacando la importancia de la experiencia y la ubicación geográfica.
# ### Nota:
# El análisis de la base "Salarios de trabajos de ciencia de datos" revela:
# - Los salarios varían por ubicación (`company_location`) y nivel de experiencia (`experience_level`), con EE.UU. liderando.
# - Los roles más comunes (`job_title`) son Data Scientist y Data Engineer.
# - La carga de trabajo por año (`work_year`) muestra un aumento en salarios.
# - No hay datos de "hora," limiting el análisis de carga horaria.
# - La ausencia de correlaciones fuertes (`corr`) indica que factores categóricos influyen más.
# Este análisis proporciona una visión clara de las tendencias salariales y la distribución de roles.

# %% [markdown]
# - OBJETIVO: Mostrar el proceso realizado por los secuenciadores de acuerdo a lo establecido en su Instrucción de Trabajo en un periodo determinado.

# %% [markdown]
# - Tabla de contenido:
#
# | Dato a Analizar | Descripción |
# | --- | --- |
# | Cliente | Menciona el cliente que está pagando el protecto |
# | Usuario | Lista de los usuarios que realizan el secuenciado |
# | Dia | Se muestra la carga de trabajo por día |
# | Hora | Se muestra la carga de trabajo por hora |
# | Tipo de SLT | Muestra la sección donde está el usuario |

# %% [markdown]
# #LIBRERIAS NUMPY Y PANDAS
#
# - NUMPY
#  Es una biblioteca de computación matemática, mas eficiente y rápida al manipular datos.
#
# - PANDAS: Facilita la manipulación de grandes volúmenes de datos a través de un conjunto de métodos y estructuras diseñadas para tal fin
#
# **FUNCIONALIDAD**
#
# 1.   CARGAR
# 2.   MODELAR
# 3.   ANALIZAR
# 4.   MANIPULAR
# 5.   PREPARAR

# %% [markdown]
# **ÍNDICE**
#
# 1.   Cargar Librerías.
# 2.   Subir Archivo.
# 3.   Leer, mostrar contenido, enlistar los primeros 5 registros.
# 4.   Se obtiene el total de registros y nombre de las columnas.
# 5.   Descripción de las columnas.
# 6.   Obtener el conteo de los registros de la base de datos.
# 7. Se valida si existen datos nulos en el DataFrame.

# %% [markdown]
# # Desarrollo del PROYECTO

# %% [markdown]
# 1. Como primer paso se deben cargar las librerías que se ocuparan en el desarrollo del código.

# %%
#Cargar librerías
import numpy as np
import pandas as pd
import os
import csv
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 2. Después de cargar las librerías que ocuparemos durante el proyecto, se indicará la ruta de acceso de la base de datos que estaremos analizando.

# %%
#Cargar csv con pd.read_csv

from google.colab import files
archivo = pd.read_csv('/content/ds_salaries.csv')

# %% [markdown]
# 3. Al tener el archivo, se muestra una tabla de contenido de los datos.

# %%
df = pd.read_csv('/content/ds_salaries.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
# Obtener los primeros 5 registros.
print('Primeros 5 registros:\n', df.head(5))
# Out:
# Primeros 5 registros:
#     Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %%
#Obtener los registros y columns de dataframe
print('Nombres de columnas:\n ', [df.columns])
print('\n')
print('Cantidad de registros en las filas: ', df.index)
# Out:
# Nombres de columnas:
#   [Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')]
#
#
# Cantidad de registros en las filas:  RangeIndex(start=0, stop=607, step=1)

# %% [markdown]
# 5.   Descripción de las columnas

# %% [markdown]
# Columna  | Descripción
# -------------------|------------------
# work_year  |  Año de ingreso
# nave      | Ubicación por nave de producción
# area  | Identificación por área del usuario
# job_title     | Detalle del área
# salary  |  Sueldo total antes de impuesto
# salary_currency      | Sueldo promedio por hora
# salary_in_usd | Sueldo en dolares
# employee_id     | Código de residencia del usuario
# remote_zone  | Código remoto de ubicacion
# company_location     | ubicacion de la compañia
# company_size |  Tamaño de la compañía

# %% [markdown]
# 6.   Obtener el conteo de los registros de la base de datos.

# %%
# Obtener el conteo de registros del Dataframe

df.count()
# Out:
# Unnamed: 0            607
# work_year             607
# experience_level      607
# employment_type       607
# job_title             607
# salary                607
# salary_currency       607
# salary_in_usd         607
# employee_residence    607
# remote_ratio          607
# company_location      607
# company_size          607
# dtype: int64

# %% [markdown]
# 7. Se valida si existen datos nulos en el DataFrame

# %%
# Verificar si existen nulos en la base
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# 8. Muestra las frecuencias de diferentes categorías. Este tipo de tabla es particularmente útil para comprender la distribución de valores en un conjunto de datos.

# %%
#Generar una frecuencia de la columna "experience_level"
df.value_counts()
# Out:
# Unnamed: 0  work_year  experience_level  employment_type  job_title                   salary   salary_currency  salary_in_usd  employee_residence  remote_ratio  company_location  company_size
# 606         2022       MI                FT               AI Scientist                200000   USD              200000         IN                  100           US                L               1
# 0           2020       MI                FT               Data Scientist              70000    EUR              79833          DE                  0             DE                L               1
# 1           2020       SE                FT               Machine Learning Scientist  260000   USD              260000         JP                  0             JP                S               1
# 2           2020       SE                FT               Big Data Engineer           85000    GBP              109024         GB                  50            GB                M               1
# ...

# %% [markdown]
# 9. Información general de los datos
# - Obtener un describe de dataframe con las columnas como registros.
# - Indica el numero de filas del dataset
# - Muestra el numero de datos No Nulos por columna (valores validos)
# - Tipo de dato de cada columna
# - Tamaño total del dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# 10. **MATRIZ DE CORRELACIÓN**
# - La correlación es una técnica estadística que muestra cómo se relacionan dos variables.
# - Se utiliza para encontrar la correlación por pares de todas las columnas en el marco de datos.
# - Cualquier valor na se excluye automáticamente.
# - Para cualquier columna de tipo de datos no numéricos en el marco de datos, se ignora.
#
# Para crear una matriz de correlación usando pandas, se deben seguir estos pasos:
#
# 1. Obtenga los datos.
# 2. Crea el DataFrame.
# 3. Crea una matriz de correlaciones.
# 4. Se genera una gráfica tipo histograma.

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# Filtra solo las columnas numéricas del DataFrame
df_numerico = df.select_dtypes(include=['number'])

# Calcula la matriz de correlación
corr = df_numerico.corr()

# Grafica el heatmap
sb.heatmap(corr, cmap="Blues", annot=True)
plt.show()

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
#Generar una gráfica de barras de la columna "employee_id"
df = pd.read_csv('/content/ds_salaries.csv', index_col='employment_type')
muestra = df[:10].copy()
muestra
# Out:
#                  Unnamed: 0  work_year experience_level  \
# employment_type
# FT                        0       2020               MI
# FT                        1       2020               SE
# FT                        2       2020               SE
# FT                        3       2020               MI
# FT                        4       2020               SE
# FT                        5       2020               EN
# FT                        6       2020               SE
# FT                        7       2020               MI
# FT                        8       2020               MI
# FT                        9       2020               SE
#
#                                   job_title    salary salary_currency  \
# employment_type
# FT                           Data Scientist     70000             EUR
# FT               Machine Learning Scientist    260000             USD
# FT                        Big Data Engineer     85000             GBP
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
muestra.groupby('job_title').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
mean_sal_jobtitle = df.groupby('job_title')['salary_in_usd'].mean().round(2).sort_values(ascending = False)
mean_sal_jobtitle
# Out:
# job_title
# Data Analytics Lead                         405000.00
# Principal Data Engineer                     328333.33
# Financial Data Analyst                      275000.00
# Principal Data Scientist                    215242.43
# Director of Data Science                    195074.00
# Data Architect                              177873.91
# Applied Data Scientist                      175655.00
# Analytics Engineer                          175000.00
# Data Specialist                             165000.00
# Head of Data                                160162.60
# Machine Learning Scientist                  158412.50
# Data Science Manager                        158328.50
# Director of Data Engineering                156738.00
# Head of Data Science                        146718.75
# Applied Machine Learning Scientist          142068.75
# Lead Data Engineer                          139724.50
# Data Analytics Manager                      127134.29
# ...

# %%
fig = px.bar(mean_sal_jobtitle, x=mean_sal_jobtitle.index, y=mean_sal_jobtitle.values,
             color=mean_sal_jobtitle.index, text=mean_sal_jobtitle.values, title='Salarios por especilidad' )
fig.update_traces(width=0.4)
fig.update_layout(
    xaxis_title="Especialidad",
    yaxis_title="Salario en dolares",
    font = dict(size=17))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Carga de datos
df = pd.read_csv('/content/ds_salaries.csv')

# %%
# Análisis de correlación de Pearson

# Filtramos las columnas numéricas
df_numerico = df.select_dtypes(include=['number'])

# Calculamos la matriz de correlación de Pearson
corr_matrix = df_numerico.corr(method='pearson')

# %%
# Imprimimos la matriz de correlación de Pearson
print(corr_matrix)
# Out:
#                Unnamed: 0  work_year    salary  salary_in_usd  remote_ratio
# Unnamed: 0       1.000000   0.886550 -0.096250       0.167025      0.095000
# work_year        0.886550   1.000000 -0.087577       0.170493      0.076314
# salary          -0.096250  -0.087577  1.000000      -0.083906     -0.014608
# salary_in_usd    0.167025   0.170493 -0.083906       1.000000      0.132122
# remote_ratio     0.095000   0.076314 -0.014608       0.132122      1.000000

# %%
corr_matrix
# Out:
#                Unnamed: 0  work_year    salary  salary_in_usd  remote_ratio
# Unnamed: 0       1.000000   0.886550 -0.096250       0.167025      0.095000
# work_year        0.886550   1.000000 -0.087577       0.170493      0.076314
# salary          -0.096250  -0.087577  1.000000      -0.083906     -0.014608
# salary_in_usd    0.167025   0.170493 -0.083906       1.000000      0.132122
# remote_ratio     0.095000   0.076314 -0.014608       0.132122      1.000000

# %%
from matplotlib import pyplot as plt
corr_matrix['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Gráficos proporcionados por pandas

# Histograma de la variable 'salary_in_usd'
plt.hist(df['salary_in_usd'])
plt.xlabel('Salario en USD')
plt.ylabel('Frecuencia')
plt.title('Histograma de salarios en USD')
plt.show()

# %%
# Diagrama de dispersión entre las variables 'work_year' y 'salary_in_usd'
sns.scatterplot(x='work_year', y='salary_in_usd', data=df)
plt.xlabel('Año de trabajo')
plt.ylabel('Salario en USD')
plt.title('Diagrama de dispersión entre el año de trabajo y el salario en USD')
plt.show()

# %%
# Diagrama de caja y bigotes de la variable 'salary_in_usd' por país
sns.boxplot(x='employee_residence', y='salary_in_usd', showmeans=True, data=df)
plt.xlabel('País de residencia')
plt.ylabel('Salario en USD')
plt.title('Diagrama de caja y bigotes de salarios en USD por país')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Mejorar codigo para mejor visualizacion**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular el salario promedio por país
top10_paises = df.groupby('employee_residence')['salary_in_usd'].mean().nlargest(10).index

# Filtrar el DataFrame para mostrar solo esos países
df_top10 = df[df['employee_residence'].isin(top10_paises)]

# Crear el gráfico
plt.figure(figsize=(12, 6))
sns.boxplot(x='employee_residence', y='salary_in_usd', data=df_top10, showmeans=True)
plt.xlabel('País de residencia (Top 10 por salario promedio)')
plt.ylabel('Salario en USD')
plt.title('Distribución de salarios en USD por país (Top 10)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Gráfico de correlación

# Creamos un mapa de calor de la matriz de correlación
plt.matshow(corr_matrix, cmap='RdYlGn')
plt.title('Matriz de correlación')
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.show()

# %% [markdown]
# Interpretación de la matriz de correlación
#
# La matriz de correlación muestra la relación lineal entre dos variables. Los valores de correlación se encuentran entre -1 y 1. Un valor de correlación de 1 indica una relación lineal positiva perfecta, un valor de correlación de -1 indica una relación lineal negativa perfecta y un valor de correlación de 0 indica que no hay relación lineal entre las dos variables.
#
# En el caso de este conjunto de datos, la variable salary_in_usd tiene una correlación positiva significativa con las variables work_year y experience_level. Esto significa que a medida que aumenta el número de años de trabajo o el nivel de experiencia, también aumenta el salario.
#
# La variable salary_in_usd también tiene una correlación negativa significativa con la variable remote_ratio. Esto significa que a medida que aumenta la proporción de trabajo remoto, disminuye el salario.
#
# La variable company_size no tiene una correlación significativa con ninguna de las otras variables. Esto significa que el tamaño de la empresa no tiene un impacto significativo en el salario.
#
# Gráfico de correlación con pandas
#
# Para crear un gráfico de correlación con pandas, podemos usar la función matshow(). Esta función crea un mapa de calor de la matriz de correlación.
#
# En el código anterior, creamos un mapa de calor de la matriz de correlación usando la función matshow(). El mapa de calor muestra que la variable salary_in_usd tiene una correlación positiva significativa con las variables work_year y experience_level.

# %% [markdown]
# #CONCLUSIONES
# - Después de analizar los datos, se puede determinar las cargas de trabajo por usuario, los salarios de cada uno y con la estadística se pueden hacer proyecciones para los siguientes años.

# %% [markdown]
# #REFERENCIAS Y LINKS DE APOYO
# https://www.codigopiton.com/como-hacer-un-histograma-en-python/
# https://cursosinformatica.ucm.es/trial/dataviz/
# https://datacarpentry.org/python-ecology-lesson-es/08-putting-it-all-together/index.html
# https://es.acervolima.com/como-crear-una-matriz-de-correlacion-usando-pandas/#:~:text=El%20m%C3%A9todo%20de%20Pandas%20dataframe,valor%20na%20se%20excluye%20autom%C3%A1ticamente.
# https://www.analyticslane.com/2020/12/07/pandas-obtener-el-nombre-de-las-columnas-y-filas-en-pandas/
